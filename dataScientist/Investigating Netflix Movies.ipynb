# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry.
#
# You work for a production company that specializes in nostalgic styles. You want to do some research on movies released in the 1990's. You'll delve into Netflix data and perform exploratory data analysis to better understand this awesome movie decade!
#
# You have been supplied with the dataset `netflix_data.csv`, along with the following table detailing the column names and descriptions. Feel free to experiment further after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# %%
# Start coding here! Use as many cells as you like
netflix_df.head(5)
# Out:
#   show_id  ...             genre
# 0      s2  ...            Dramas
# 1      s3  ...     Horror Movies
# 2      s4  ...            Action
# 3      s5  ...            Dramas
# 4      s6  ...  International TV
#
# [5 rows x 11 columns]

# %%
data = netflix_df.loc[:,['release_year','duration']]

# %%
data.head(10)
# Out:
#    release_year  duration
# 0          2016        93
# 1          2011        78
# 2          2009        80
# 3          2008       123
# 4          2016         1
# 5          2019        95
# 6          1997       119
# 7          2019       118
# 8          2008       143
# 9          2017       103

# %%
df_1990s = data[(data['release_year'] >= 1990) & (data['release_year'] < 2000)]

# %%
df_1990s
# Out:
#       release_year  duration
# 6             1997       119
# 118           1993       101
# 145           1998        82
# 167           1996       108
# 194           1993       154
# ...            ...       ...
# 4672          1999       106
# 4689          1993       118
# 4718          1999       106
# 4746          1994       191
# 4756          1994       148
#
# [184 rows x 2 columns]

# %%
duration = int(df_1990s['duration'].mode()[0])

# %%
plt.scatter(df_1990s['release_year'],df_1990s['duration'])
plt.show()

# %%
print(duration)
# Out:
# 94

# %%
data1 = netflix_df.loc[:,['release_year','duration','genre']]

# %%
data1.head(10)
# Out:
#    release_year  duration             genre
# 0          2016        93            Dramas
# 1          2011        78     Horror Movies
# 2          2009        80            Action
# 3          2008       123            Dramas
# 4          2016         1  International TV
# 5          2019        95     Horror Movies
# 6          1997       119            Dramas
# 7          2019       118     Horror Movies
# 8          2008       143     Horror Movies
# 9          2017       103            Dramas

# %%
df = data1 [ (data1['release_year'] >= 1990) & (data1['release_year'] < 2000)]

# %%
df
# Out:
#       release_year  duration           genre
# 6             1997       119          Dramas
# 118           1993       101          Dramas
# 145           1998        82        Comedies
# 167           1996       108        Comedies
# 194           1993       154          Dramas
# ...            ...       ...             ...
# 4672          1999       106          Dramas
# 4689          1993       118  Classic Movies
# 4718          1999       106          Action
# 4746          1994       191          Action
# 4756          1994       148          Dramas
#
# [184 rows x 3 columns]

# %%
action_1990s = df[(df['genre'] == 'Action')]

# %%
action_1990s
# Out:
#       release_year  duration   genre
# 352           1994       160  Action
# 431           1999        95  Action
# 468           1995       119  Action
# 515           1995       166  Action
# 675           1999        94  Action
# 815           1992       125  Action
# 816           1992       108  Action
# 1018          1997       108  Action
# 1179          1996       103  Action
# 1288          1998        69  Action
# 1299          1996       133  Action
# 1504          1990       163  Action
# 1515          1997       161  Action
# 1548          1995       130  Action
# 1599          1993       149  Action
# 1661          1999       151  Action
# 1688          1999       126  Action
# 1698          1997        89  Action
# 2050          1992        95  Action
# 2124          1993       170  Action
# 2282          1997       104  Action
# 2313          1998       108  Action
# 2328          1990        88  Action
# 2356          1994        93  Action
# ...

# %%
count = action_1990s[(action_1990s['duration'] < 90)]

# %%
short_movie_count = len(count)

# %%
print(short_movie_count)
# Out:
# 7
